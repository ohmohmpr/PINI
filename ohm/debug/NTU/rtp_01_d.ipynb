# %%
import numpy as np
import matplotlib.pyplot as plt
from util import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pini_data = np.loadtxt('/home/ohmpr/master_bonn/Modules/thesis/Pinocchio/experiments/ntu/rtp_01_PINI_1000/state.txt', delimiter=',', unpack=True)
lio_ekf_data = np.loadtxt('/home/ohmpr/master_bonn/Modules/thesis/Pinocchio/experiments/ntu/rtp_01_LIO_EKF/state.txt', delimiter=',', unpack=True)

# %%
# start_time_idx = 100 * 10
# end_time_idx = - (40) * 10
start_time_idx = 0
end_time_idx = -1

# %%
plot_everything(pini_data, lio_ekf_data, 'translation', start_time_idx, end_time_idx)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_everything(pini_data, lio_ekf_data, 'translation', start_time_idx, end_time_idx)
#
# File ~/master_bonn/Modules/thesis/Pinocchio/ohm/debug/NTU/util.py:43, in plot_everything(pini_data, lio_ekf_data, title, start_time_idx, end_time_idx)
#      41 plot_delta_x(delta_x_lio_ekf_data, None, delta_x_pini_data, None, title, start_time_idx, end_time_idx, 'delta_x', point_diff_lio_ekf_data)
#      42 plot_delta_x(cov_lio_ekf_data, None, cov_pini_data, None, title, start_time_idx, end_time_idx, 'cov', point_diff_lio_ekf_data)
# ---> 43 plot_delta_x(n_lio_ekf_data, None, n_pini_data, None, title, start_time_idx, end_time_idx, 'N', point_diff_lio_ekf_data)
#
# File ~/master_bonn/Modules/thesis/Pinocchio/ohm/debug/NTU/util.py:63, in plot_delta_x(pred_data_LIO_EKF, update_data_LIO_EKF, pred_data_PINI, update_data_PINI, title, start_time_idx, end_time_idx, del_name, point_diff)
#      59   label_idx = 15
#      61 figure, axis = plt.subplots(4, 1, sharex=True, figsize=(12, 9))
# ---> 63 axis[0].plot(pred_data_PINI[0, start_time_idx:end_time_idx] - pred_data_PINI[0,0], pred_data_PINI[label_idx  , start_time_idx:end_time_idx], 'r-', label='x_PINI') # x
#      64 axis[1].plot(pred_data_PINI[0, start_time_idx:end_time_idx] - pred_data_PINI[0,0], pred_data_PINI[label_idx+1, start_time_idx:end_time_idx], 'g-', label='y_PINI') # y
#      65 axis[2].plot(pred_data_PINI[0, start_time_idx:end_time_idx] - pred_data_PINI[0,0], pred_data_PINI[label_idx+2, start_time_idx:end_time_idx], 'b-', label='z_PINI') # z
#
# IndexError: index 0 is out of bounds for axis 1 with size 0

# %%
plot_everything(pini_data, lio_ekf_data, 'velocity', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'rotation', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'gyro_bias', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'acc_bias', start_time_idx, end_time_idx)
