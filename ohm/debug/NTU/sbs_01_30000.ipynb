# %%
import numpy as np
import matplotlib.pyplot as plt
from util import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pini_data = np.loadtxt('/home/ohmpr/master_bonn/Modules/thesis/Pinocchio/experiments/ntu/sbs_01_PINI_30000/state.txt', delimiter=',', unpack=True)
lio_ekf_data = np.loadtxt('/home/ohmpr/master_bonn/Modules/thesis/Pinocchio/experiments/ntu/sbs_01_LIO_EKF/state.txt', delimiter=',', unpack=True)

# %%
# start_time_idx = 100 * 10
# end_time_idx = - (40) * 10
start_time_idx = 0
end_time_idx = -1
# end_time_idx = 50 * 10

# %%
plot_everything(pini_data, lio_ekf_data, 'translation', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'velocity', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'rotation', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'gyro_bias', start_time_idx, end_time_idx)

# %%
plot_everything(pini_data, lio_ekf_data, 'acc_bias', start_time_idx, end_time_idx)
